# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinDLopez/MammographyAI/blob/main/GoogLetNetV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
data_dir = '/content/drive/MyDrive/ddsm-mammography/'
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# from utils.data_download import download_data_with_animation, unzip_data
# from utils.read_tensorflow_data import read_tf_data, data_type, create_tf_dataset
# from utils.plotting import plot_histories
import os
from typing import List, Tuple, TypedDict, Dict
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


from keras.models import Sequential
from keras import layers, models
from keras.callbacks import ModelCheckpoint
from keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    concatenate,
    Dropout,
    Dense,
    Flatten,
    BatchNormalization,
    Activation,
    AveragePooling2D,
    Add,
    Dropout,
    MaxPool2D,
    GlobalAveragePooling2D,
)
import tensorflow as tf
from keras.models import Sequential, Model, load_model
from keras.metrics import Recall
from keras.metrics import Precision

# %%
import tensorflow as tf
from typing import List, Tuple, TypedDict
import numpy as np

data_type = TypedDict("data_type", {"label": List[np.number], "data": List[tf.Tensor]})


def read_tf_data(file: str, storing_dict: data_type):
    def parse_function(example_proto):
        return tf.io.parse_single_example(
            example_proto,
            {
                "label": tf.io.FixedLenFeature([], tf.int64),
                "label_normal": tf.io.FixedLenFeature([], tf.int64),
                "image": tf.io.FixedLenFeature([], tf.string),
            },
        )

    # Extract the data
    with tf.device("/CPU:0"):  # else is filled with GPU memory # type: ignore
        raw_data = tf.data.TFRecordDataset([file])
        parsed_dataset = raw_data.map(parse_function)

    for element in parsed_dataset:
        with tf.device("/CPU:0"):  # else is filled with GPU memory # type: ignore
            image = tf.io.decode_raw(
                element["image"], tf.uint8
            )  # shape = (89401,0) - 299*299 = 89401
            image = tf.reshape(image, [299, 299, 1])  # gray scale image
            label = np.int8(element["label_normal"].numpy())
            storing_dict["label"].append(label)
            storing_dict["data"].append(image)


# allocating the data to the memory, with a small batch size. Previously the training was not happening.
def create_tf_dataset(data_dict):
    def generator(data, labels):
        for d, l in zip(data, labels):
            yield d, l

    # Convert the data to TensorFlow Datasets
    dataset = tf.data.Dataset.from_generator(
        generator,
        args=[data_dict["data"], data_dict["label"]],
        output_signature=(
            tf.TensorSpec(shape=(299, 299, 1), dtype=tf.uint8),  # type: ignore
            tf.TensorSpec(shape=(), dtype=tf.uint8),  # type: ignore
        ),
    )
    dataset = dataset.shuffle(buffer_size=2048)

    return dataset



import matplotlib.pyplot as plt
from typing import List, Tuple, TypedDict, Dict

def plot_histories(histories:List[ Dict[str, List[int]]], log_scale=False):
    '''Plot the training and validation loss and accuracy of the models in the histories list
    histories: List of histories dictionaries
    '''
    plt.figure(figsize=(10, 15))

    history_dictionary : Dict[str, List[int] ]  = {}
    # make a whole array from the elements of the dictionary
    for history in histories:
        for plt_name, values in history.items():
            if plt_name not in history_dictionary:
                history_dictionary[plt_name] = []
            history_dictionary[plt_name].extend(values)


    plt.subplot(len(history_dictionary)//2,1,1)
    plt.title('Loss')
    plt.plot(history_dictionary['loss'], label='Training Loss')
    plt.plot(history_dictionary['val_loss'], label='Validation Loss')
    if log_scale:
        plt.yscale("log")
    plt.legend()

    plt.subplot(len(history_dictionary)//2,1,2)
    plt.title('Accuracy')
    plt.plot(history_dictionary['accuracy'], label='Training Accuracy')
    plt.plot(history_dictionary['val_accuracy'], label='Validation Accuracy')
    if log_scale:
        plt.yscale("log")
    plt.legend()

    plt.subplot(len(history_dictionary)//2,1,3)
    plt.title("Recall")
    plt.plot(history_dictionary['recall'], label='Training Recall')
    plt.plot(history_dictionary['val_recall'], label='Validation Recall')
    if log_scale:
        plt.yscale("log")
    plt.legend()

    if "precision" in history_dictionary:
        plt.subplot(len(history_dictionary)//2,1,4)
        plt.title("precision")
        plt.plot(history_dictionary['precision'], label='Training precision')
        plt.plot(history_dictionary['val_precision'], label='Validation precision')
        if log_scale:
            plt.yscale("log")
        plt.legend()

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk(data_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /content/drive/MyDrive/ddsm-mammography/cv10_labels.npy
# /content/drive/MyDrive/ddsm-mammography/test10_labels.npy
# /content/drive/MyDrive/ddsm-mammography/cv10_data/cv10_data.npy
# /content/drive/MyDrive/ddsm-mammography/test10_data/test10_data.npy
# /content/drive/MyDrive/ddsm-mammography/training10_0/training10_0.tfrecords
# /content/drive/MyDrive/ddsm-mammography/training10_1/training10_1.tfrecords
# /content/drive/MyDrive/ddsm-mammography/training10_2/training10_2.tfrecords
# /content/drive/MyDrive/ddsm-mammography/training10_3/training10_3.tfrecords
# /content/drive/MyDrive/ddsm-mammography/training10_4/training10_4.tfrecords

# %%
data_files = []
for root, dirs, files in os.walk(data_dir) :
	for file in files:
		data_files.append( os.path.join(root, file).replace('\\', '/') )

data_files
# Out:
# ['/content/drive/MyDrive/ddsm-mammography/cv10_labels.npy',
#  '/content/drive/MyDrive/ddsm-mammography/test10_labels.npy',
#  '/content/drive/MyDrive/ddsm-mammography/cv10_data/cv10_data.npy',
#  '/content/drive/MyDrive/ddsm-mammography/test10_data/test10_data.npy',
#  '/content/drive/MyDrive/ddsm-mammography/training10_0/training10_0.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_1/training10_1.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_2/training10_2.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_3/training10_3.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_4/training10_4.tfrecords']

# %%
training_files = [file for file in data_files if "training" in file]
training_files
# Out:
# ['/content/drive/MyDrive/ddsm-mammography/training10_0/training10_0.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_1/training10_1.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_2/training10_2.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_3/training10_3.tfrecords',
#  '/content/drive/MyDrive/ddsm-mammography/training10_4/training10_4.tfrecords']

# %%
training_data :data_type = {"label": [], "data": []}

for training_file in training_files:
	read_tf_data( training_file, training_data )

# %%
plt.figure(figsize=(10, 5))

sns.countplot(x=training_data['label'])
plt.title("Training data")
# add labels on top of the data
# add labels on top of the data( note there is only 2 cathegories 1, 0)
for i in range(2):
	plt.text(i, training_data['label'].count(i), training_data['label'].count(i), ha = 'center')  # type: ignore
plt.show()

# %%
def augment(image, lower_c=0.8, high_c=1.0)-> tf.Tensor:
    with tf.device("/CPU:0"):
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_flip_up_down(image)
        image = tf.image.random_brightness(image, max_delta=0.25)
        image = tf.image.random_contrast(image, lower=lower_c, upper=high_c)
        image = tf.image.random_jpeg_quality(image, min_jpeg_quality=60, max_jpeg_quality=99)
        return image # type: ignore

augmented_images = []
augmented_labels = []
shown_once = 0
for label, image in zip(training_data["label"], training_data["data"]):
    # augment 3, positive, 1 negative
    if label == 1:
        img1 = augment(image)
        img2 = augment(image, lower_c=1, high_c=1.3)
        img3 = augment(image, lower_c=0.8, high_c=1.2)
        img4 = augment(image, lower_c=0.8, high_c=1.2)
        img6 = augment(image, lower_c=0.8, high_c=1.2)
        img7 = augment(image, lower_c=0.7, high_c=1.3)
        augmented_images.extend([img1,  img2,   img3,   img4,   img6,   img7 ])
        augmented_labels.extend([label, label,  label,  label,  label,  label])
        if shown_once<5: # To only show images once
            shown_once +=1
            plt.figure(figsize=(8, 3))
            plt.subplot(1, 5, 1)
            plt.imshow(image)
            plt.title('original')
            plt.axis("off")
            plt.subplot(1, 5, 2)
            plt.imshow(img1)
            plt.axis("off")
            plt.subplot(1, 5, 3)
            plt.imshow(img2)
            plt.axis("off")
            plt.subplot(1, 5, 4)
            plt.imshow(img3)
            plt.axis("off")
            plt.subplot(1, 5, 5)
            plt.imshow(img4)
            plt.axis("off")
            plt.show()
    img5 = augment(image)
    augmented_images.extend([img5])
    augmented_labels.extend([label])

training_data["label"].extend(augmented_labels)
training_data["data"].extend(augmented_images)

# %%
import random

def shuffle(data_labels:data_type):
    # Create a list of indices from 0 to the length of data
    indices = list(range(len(data_labels['data'])))

    # Shuffle the indices
    random.shuffle(indices)

    # Use the shuffled indices to reorder data and labels
    shuffled_data = [data_labels['data'][i] for i in indices]
    shuffled_labels = [data_labels["label"][i] for i in indices]

    return shuffled_data, shuffled_labels

training_data['data'], training_data["label"] = shuffle(training_data)
training_data['data'], training_data["label"] = shuffle(training_data) # shuffle twice for better

# %%
plt.figure(figsize=(10, 5))

sns.countplot(x=training_data['label'])
plt.title("Training data")
# add labels on top of the data
# add labels on top of the data( note there is only 2 cathegories 1, 0)
for i in range(2):
	plt.text(i, training_data['label'].count(i), training_data['label'].count(i), ha = 'center')  # type: ignore
plt.show()

# %%
nrows = 2
ncols = 5

plt.figure(figsize=(20, 5))
for i in range(nrows*ncols):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(training_data["data"][i], )
    plt.title(str(training_data["label"][i]))
    # Remove the axis
    plt.axis('off')

# Show the plot
# plt.subplots_adjust(wspace=0.01, hspace=0.01)
plt.show()

# %%
test_files =  f'{data_dir}/test10_data/test10_data.npy'
test_files_labels =  f'{data_dir}/test10_labels.npy'

cross_validation_files =  f'{data_dir}/cv10_data/cv10_data.npy'
cross_validation_files_labels = f'{data_dir}/cv10_labels.npy'



# Note this data is ng, cv_data only contains masses, test_data only contains calcifications.
test_data_ng = np.load( test_files)
test_data_labels = np.load(  test_files_labels)
cv_data_ng = np.load( cross_validation_files)
cv_data_labels = np.load( cross_validation_files_labels)

# %%
#
cv_data : data_type = {'data': [], 'label': []}
test_data : data_type = {'data': [], 'label': []}
n_test = []  # data, label
n_cv = [] # data, label
for i in range( len(cv_data_ng)):
	if i%2: # odd
		n_test.append(   (cv_data_ng[i], cv_data_labels[i])   )
		n_test.append(   (test_data_ng[i], test_data_labels[i])   )
	else:
		n_cv.append(   (cv_data_ng[i], cv_data_labels[i])   )
		n_cv.append(   (test_data_ng[i], test_data_labels[i])   )

cv_data['data'] = [x[0] for x in n_cv]
cv_data['label'] = [np.int8(1) if x[1]>0 else np.int8(0) for x in n_cv]

test_data['data'] = [x[0] for x in n_test]
test_data['label'] = [np.int8(1) if x[1]>0 else np.int8(0) for x in n_test]

# %%
nrows = 2
ncols = 5

plt.figure(figsize=(20, 5))
for i in range(nrows*ncols):
    plt.subplot(nrows, ncols, i+1)
    plt.imshow(cv_data["data"][i], )
    plt.title(str(cv_data["label"][i]))
    # Remove the axis
    plt.axis('off')

plt.show()

# %%
train_dataset = create_tf_dataset(training_data).batch(300).prefetch(tf.data.AUTOTUNE)

# %%
cv_dataset = create_tf_dataset( cv_data).batch(32).prefetch(tf.data.AUTOTUNE)  # DatasetV2

# %%
# Find the weights for each class
ones = 0
zeros = 0
for label in training_data['label']:
	if label == 1:
		ones += 1
	else:
		zeros += 1

total = ones + zeros

weights_dict = {0: (1/zeros) * (total/2), 1: (1/ones) * (total/2)}
weights_dict
# Out:
# {0: 0.7999835377397316, 1: 1.3333790643435313}

# %%
print(f'ones = {ones}, zeros={zeros}, total={total}')
# Out:
# ones = 58312, zeros=97192, total=155504

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Dropout, Dense, Flatten, BatchNormalization, Activation, AveragePooling2D, Add, MaxPool2D, GlobalAveragePooling2D
from keras.models import Model
# from keras.applications.inception_v3 import InceptionV3
from keras.optimizers import Adam, SGD
from keras import regularizers


reg = regularizers.l2(0.01)

# 64, 96, 128, 16, 32, 192, 32
def inception_module_v3(x, filters:List[int], dropout_rate=0.2):
    # 1x1 convolution
    conv1x1 = None
    if filters[0]:
        conv1x1 = Conv2D(filters[0], (1, 1), padding='same',   )(x) # 299x299 x filter[0]
        conv1x1 = BatchNormalization()(conv1x1)                 # 299x299 x filter[0]
        conv1x1 = Activation('relu')(conv1x1)                   # 2

    conv3x3 = None
    # 3x3 convolution
    if filters[2] and filters[1]:
        conv3x3 = Conv2D(filters[1], (1, 1), padding='same', )(x)
        conv3x3 = BatchNormalization()(conv3x3)
        conv3x3 = Activation('relu')(conv3x3)
        conv3x3 = Conv2D(filters[2], (3, 3), padding='same', kernel_regularizer=reg)(conv3x3)
        conv3x3 = BatchNormalization()(conv3x3)
        conv3x3 = Activation('relu')(conv3x3)
        conv3x3 = Dropout(dropout_rate)(conv3x3)  # Dropout added

    # Factored 5x5 convolution as two 3x3 convolutions
    conv5x5 = None
    if filters[3]!=0 and filters[4]!=0:
        conv5x5 = Conv2D(filters[3], (1, 1), padding='same' )(x)
        conv5x5 = BatchNormalization()(conv5x5)
        conv5x5 = Activation('relu')(conv5x5)
        conv5x5 = Conv2D(filters[4], (3, 3), padding='same', kernel_regularizer=reg )(conv5x5)
        conv5x5 = BatchNormalization()(conv5x5)
        conv5x5 = Activation('relu')(conv5x5)
        conv5x5 = Conv2D(filters[4], (3, 3), padding='same', kernel_regularizer=reg)(conv5x5)
        conv5x5 = BatchNormalization()(conv5x5)
        conv5x5 = Activation('relu')(conv5x5)
        conv5x5 = Dropout(dropout_rate)(conv5x5)  # Dropout added

    # 7x7 convolution as three 3x3 convolutions
    conv7x7 = None
    if filters[5]!=0 and filters[6]!=0:
        conv7x7 = Conv2D( filters[5], (1,1), padding='same',)(x)
        conv7x7 = BatchNormalization()(conv7x7)
        conv7x7 = Activation('relu')(conv7x7)
        conv7x7 = Conv2D(filters[6], (3,3), padding='same', )(x)
        conv7x7 = BatchNormalization()(conv7x7)
        conv7x7 = Activation('relu')(conv7x7)
        conv7x7 = Conv2D(filters[6], (3,3), padding='same', kernel_regularizer=reg)(x)
        conv7x7 = BatchNormalization()(conv7x7)
        conv7x7 = Activation('relu')(conv7x7)
        conv7x7 = Conv2D(filters[6], (3,3), padding='same', kernel_regularizer=reg)(x)
        conv7x7 = BatchNormalization()(conv7x7)
        conv7x7 = Activation('relu')(conv7x7)
        conv7x7 = Dropout(dropout_rate)(conv7x7)  # Dropout added


    # MaxPooling with 1x1 convolution projection
    pool_proj = None
    if filters[7]:
        pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
        pool_proj = Conv2D(filters[7], (1, 1), padding='same')(pool_proj)
        pool_proj = BatchNormalization()(pool_proj)
        pool_proj = Activation('relu')(pool_proj)
        pool_proj = Dropout(dropout_rate)(pool_proj)  # Dropout added

    conv5x5_real = None
    if len(filters)>8 and filters[8]:
        conv5x5_real = Conv2D(filters[8]//2, (5, 5), padding='same',   )(x)
        conv5x5_real = BatchNormalization()(conv5x5_real)
        conv5x5_real = Activation('relu')(conv5x5_real)
        conv5x5_real = Conv2D(filters[8], (3, 3), padding='same',  kernel_regularizer=reg )(conv5x5_real)
        conv5x5_real = BatchNormalization()(conv5x5_real)
        conv5x5_real = Activation('relu')(conv5x5_real)
        conv5x5_real = Conv2D(filters[8], (1, 1), padding='same', )(conv5x5_real)
        conv5x5_real = BatchNormalization()(conv5x5_real)
        conv5x5_real = Activation('relu')(conv5x5_real)
        conv5x5_real = Dropout(dropout_rate)(conv5x5_real)  # Dropout added

    # Concatenate all the convolutions
    output_layers = [layer for layer in [conv1x1, conv5x5, conv3x3, conv7x7, pool_proj, conv5x5_real] if layer is not None]
    output = concatenate(output_layers)
    return output

def create_googlenet_v2()->Model:
    input_layer = Input(shape=(299, 299, 1))
    x = Conv2D(128, (5, 5),  strides=(2, 2), padding="same" )(input_layer)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (5, 5),  padding="valid"  )(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D((5, 5), strides=(2, 2), padding='valid')(x)
    x = layers.Dropout(0.4)(x)

    # 64, 96, 128, 16, 32, 192, 32
    x = inception_module_v3(x, [64, 0, 0, 64, 32, 4, 8, 32, 64])
    x = AveragePooling2D((5, 5), strides=(3, 3), padding='same')(x)
    x = inception_module_v3(x, [0, 32, 64, 0, 0, 16, 64, 0])
    x = AveragePooling2D((5, 5), strides=(3, 3), padding='same')(x)
    x = inception_module_v3(x, [128, 0, 0, 64, 128, 32, 58, 32, 128])

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(1, activation='sigmoid', kernel_regularizer=reg)(x)  # Use sigmoid activation for binary classification
    model = Model(inputs=input_layer, outputs=x)
    return model

from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau


model_g_custom = create_googlenet_v2()
model_g_custom.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 1)]        0         []
#
#  conv2d (Conv2D)             (None, 150, 150, 128)        3328      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 150, 150, 128)        512       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 150, 150, 128)        0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)         102432    ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 146, 146, 32)         128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 146, 146, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 71, 71, 32)           0         ['activation_1[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 71, 71, 32)           0         ['average_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 71, 71, 64)           2112      ['dropout[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 71, 71, 32)           25632     ['dropout[0][0]']
#
#  batch_normalization_3 (Bat  (None, 71, 71, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 71, 71, 32)           128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 71, 71, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_11 (Activation)  (None, 71, 71, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_4 (Conv2D)           (None, 71, 71, 32)           18464     ['activation_3[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 71, 71, 64)           18496     ['activation_11[0][0]']
#
#  batch_normalization_4 (Bat  (None, 71, 71, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, 71, 71, 64)           256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_4 (Activation)   (None, 71, 71, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 71, 71, 32)           0         ['dropout[0][0]']
#  D)
#
#  activation_12 (Activation)  (None, 71, 71, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_5 (Conv2D)           (None, 71, 71, 32)           9248      ['activation_4[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 71, 71, 8)            2312      ['dropout[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 71, 71, 32)           1056      ['max_pooling2d[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 71, 71, 64)           4160      ['activation_12[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)           2112      ['dropout[0][0]']
#
#  batch_normalization_5 (Bat  (None, 71, 71, 32)           128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 71, 71, 8)            32        ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 71, 71, 32)           128       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 71, 71, 64)           256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_2 (Bat  (None, 71, 71, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 71, 71, 32)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 71, 71, 8)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 71, 71, 32)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_13 (Activation)  (None, 71, 71, 64)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_2 (Activation)   (None, 71, 71, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 71, 71, 32)           0         ['activation_5[0][0]']
#
#  dropout_2 (Dropout)         (None, 71, 71, 8)            0         ['activation_9[0][0]']
#
#  dropout_3 (Dropout)         (None, 71, 71, 32)           0         ['activation_10[0][0]']
#
#  dropout_4 (Dropout)         (None, 71, 71, 64)           0         ['activation_13[0][0]']
#
#  concatenate (Concatenate)   (None, 71, 71, 200)          0         ['activation_2[0][0]',
#                                                                      'dropout_1[0][0]',
#                                                                      'dropout_2[0][0]',
#                                                                      'dropout_3[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 24, 24, 200)          0         ['concatenate[0][0]']
#  gePooling2D)
#
#  conv2d_14 (Conv2D)          (None, 24, 24, 32)           6432      ['average_pooling2d_1[0][0]']
#
#  batch_normalization_14 (Ba  (None, 24, 24, 32)           128       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 24, 24, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 24, 24, 64)           18496     ['activation_14[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 64)           115264    ['average_pooling2d_1[0][0]']
#
#  batch_normalization_15 (Ba  (None, 24, 24, 64)           256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 24, 24, 64)           256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 24, 24, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_19 (Activation)  (None, 24, 24, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 24, 24, 64)           0         ['activation_15[0][0]']
#
#  dropout_6 (Dropout)         (None, 24, 24, 64)           0         ['activation_19[0][0]']
#
#  concatenate_1 (Concatenate  (None, 24, 24, 128)          0         ['dropout_5[0][0]',
#  )                                                                   'dropout_6[0][0]']
#
#  average_pooling2d_2 (Avera  (None, 8, 8, 128)            0         ['concatenate_1[0][0]']
#  gePooling2D)
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 64)             8256      ['average_pooling2d_2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 8, 8, 64)             204864    ['average_pooling2d_2[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 64)             256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 8, 8, 64)             256       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)            73856     ['activation_21[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 8, 8, 128)            73856     ['activation_29[0][0]']
#
#  batch_normalization_22 (Ba  (None, 8, 8, 128)            512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 8, 8, 128)            512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)            0         ['average_pooling2d_2[0][0]']
#  g2D)
#
#  activation_30 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_22[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 8, 8, 58)             66874     ['average_pooling2d_2[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 32)             4128      ['max_pooling2d_1[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)            16512     ['activation_30[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 128)            16512     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_23 (Ba  (None, 8, 8, 128)            512       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 8, 8, 58)             232       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 8, 8, 32)             128       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 8, 8, 128)            512       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 8, 8, 128)            512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  activation_27 (Activation)  (None, 8, 8, 58)             0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 8, 8, 32)             0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_31 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 8, 8, 128)            0         ['activation_23[0][0]']
#
#  dropout_8 (Dropout)         (None, 8, 8, 58)             0         ['activation_27[0][0]']
#
#  dropout_9 (Dropout)         (None, 8, 8, 32)             0         ['activation_28[0][0]']
#
#  dropout_10 (Dropout)        (None, 8, 8, 128)            0         ['activation_31[0][0]']
#
#  concatenate_2 (Concatenate  (None, 8, 8, 474)            0         ['activation_20[0][0]',
#  )                                                                   'dropout_7[0][0]',
#                                                                      'dropout_8[0][0]',
#                                                                      'dropout_9[0][0]',
#                                                                      'dropout_10[0][0]']
#
#  global_average_pooling2d (  (None, 474)                  0         ['concatenate_2[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout_11 (Dropout)        (None, 474)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 1)                    475       ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 948741 (3.62 MB)
# Trainable params: 945601 (3.61 MB)
# Non-trainable params: 3140 (12.27 KB)
# __________________________________________________________________________________________________

# %%
model_g_custom = create_googlenet_v2()
best_loss = "./content/drive/MyDrive/ddsm-mammography/models/custom_g/best_val_loss.keras"
best_recall = "./content/drive/MyDrive/ddsm-mammography/models/custom_g/best_val_recall.keras"
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.01, min_lr=0.00)
early_stopping = EarlyStopping(monitor='val_loss', patience=8, mode='min', restore_best_weights=True)
best_val_recall_checkpoint = ModelCheckpoint(best_loss, monitor='val_recall', save_best_only=True)
best_val_loss_checkpoint = ModelCheckpoint(best_recall, monitor='val_loss', save_best_only=True)
model_g_custom.compile(optimizer=SGD(learning_rate=2**(-5)), loss='binary_crossentropy', metrics=['accuracy', Recall(name='recall'), Precision(name='precision')])

# train the model first with weights so that it can focus on recognizing cancer testcases
model_g_history = model_g_custom.fit(train_dataset,
                                     validation_data=cv_dataset,
                                     epochs=50,
                                     callbacks=[best_val_recall_checkpoint, best_val_loss_checkpoint, early_stopping, lr_reduction],
                                     class_weight=weights_dict #
                                     )

model_g_custom.save('./content/drive/MyDrive/ddsm-mammography/models/custom_g/latest_50.keras')
# Out:
# Epoch 1/35
# 519/519 [==============================] - 348s 447ms/step - loss: 5.2956 - accuracy: 0.7446 - recall: 0.7745 - precision: 0.6296 - val_loss: 4.1530 - val_accuracy: 0.8655 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 0.0312
# Epoch 2/35
# 519/519 [==============================] - 196s 376ms/step - loss: 2.9226 - accuracy: 0.8020 - recall: 0.8321 - precision: 0.6980 - val_loss: 2.0899 - val_accuracy: 0.8743 - val_recall: 0.2672 - val_precision: 0.5691 - lr: 0.0312
# Epoch 3/35
# 519/519 [==============================] - 196s 376ms/step - loss: 1.6979 - accuracy: 0.8224 - recall: 0.8463 - precision: 0.7257 - val_loss: 1.5383 - val_accuracy: 0.8657 - val_recall: 9.6805e-04 - val_precision: 1.0000 - lr: 0.0312
# Epoch 4/35
# 519/519 [==============================] - 196s 376ms/step - loss: 1.0563 - accuracy: 0.8344 - recall: 0.8535 - precision: 0.7431 - val_loss: 1.0790 - val_accuracy: 0.6351 - val_recall: 0.8751 - val_precision: 0.2527 - lr: 0.0312
# Epoch 5/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.7142 - accuracy: 0.8453 - recall: 0.8605 - precision: 0.7591 - val_loss: 0.5938 - val_accuracy: 0.8810 - val_recall: 0.5286 - val_precision: 0.5612 - lr: 0.0312
# Epoch 6/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.5248 - accuracy: 0.8581 - recall: 0.8703 - precision: 0.7778 - val_loss: 0.5184 - val_accuracy: 0.8542 - val_recall: 0.6331 - val_precision: 0.4688 - lr: 0.0312
# Epoch 7/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.4226 - accuracy: 0.8666 - recall: 0.8761 - precision: 0.7908 - val_loss: 0.4524 - val_accuracy: 0.8435 - val_recall: 0.7251 - val_precision: 0.4493 - lr: 0.0312
# Epoch 8/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.3588 - accuracy: 0.8774 - recall: 0.8860 - precision: 0.8062 - val_loss: 0.5727 - val_accuracy: 0.8042 - val_recall: 0.8248 - val_precision: 0.3917 - lr: 0.0312
# Epoch 9/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.3198 - accuracy: 0.8864 - recall: 0.8947 - precision: 0.8192 - val_loss: 0.3718 - val_accuracy: 0.8741 - val_recall: 0.0833 - val_precision: 0.8113 - lr: 0.0312
# Epoch 10/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.3012 - accuracy: 0.8903 - recall: 0.8980 - precision: 0.8250 - val_loss: 0.7896 - val_accuracy: 0.5844 - val_recall: 0.9390 - val_precision: 0.2366 - lr: 0.0312
# Epoch 11/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.2792 - accuracy: 0.8991 - recall: 0.9052 - precision: 0.8385 - val_loss: 0.4000 - val_accuracy: 0.8395 - val_recall: 0.6602 - val_precision: 0.4361 - lr: 0.0312
# Epoch 12/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.2654 - accuracy: 0.9045 - recall: 0.9093 - precision: 0.8472 - val_loss: 0.3204 - val_accuracy: 0.8680 - val_recall: 0.6689 - val_precision: 0.5070 - lr: 0.0312
# Epoch 13/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.2531 - accuracy: 0.9094 - recall: 0.9146 - precision: 0.8542 - val_loss: 0.6257 - val_accuracy: 0.8658 - val_recall: 0.0019 - val_precision: 1.0000 - lr: 0.0312
# Epoch 14/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.2441 - accuracy: 0.9138 - recall: 0.9180 - precision: 0.8613 - val_loss: 1.1760 - val_accuracy: 0.8655 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 0.0312
# Epoch 15/35
# 519/519 [==============================] - 196s 376ms/step - loss: 0.2393 - accuracy: 0.9167 - recall: 0.9210 - precision: 0.8655 - val_loss: 0.2683 - val_accuracy: 0.9095 - val_recall: 0.4134 - val_precision: 0.8275 - lr: 0.0312
# Epoch 16/35
# 519/519 [==============================] - 195s 376ms/step - loss: 0.2357 - accuracy: 0.9178 - recall: 0.9211 - precision: 0.8677 - val_loss: 0.2184 - val_accuracy: 0.9293 - val_recall: 0.6312 - val_precision: 0.8010 - lr: 0.0312
# Epoch 17/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.2220 - accuracy: 0.9247 - recall: 0.9287 - precision: 0.8776 - val_loss: 0.3522 - val_accuracy: 0.8478 - val_recall: 0.8625 - val_precision: 0.4645 - lr: 0.0312
# Epoch 18/35
# 519/519 [==============================] - 195s 374ms/step - loss: 0.2176 - accuracy: 0.9259 - recall: 0.9295 - precision: 0.8797 - val_loss: 0.2936 - val_accuracy: 0.8925 - val_recall: 0.2682 - val_precision: 0.7983 - lr: 0.0312
# Epoch 19/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.2119 - accuracy: 0.9289 - recall: 0.9319 - precision: 0.8846 - val_loss: 0.2229 - val_accuracy: 0.9283 - val_recall: 0.4966 - val_precision: 0.9430 - lr: 0.0312
# Epoch 20/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1832 - accuracy: 0.9400 - recall: 0.9498 - precision: 0.8964 - val_loss: 0.1455 - val_accuracy: 0.9560 - val_recall: 0.7367 - val_precision: 0.9202 - lr: 3.1250e-04
# Epoch 21/35
# 519/519 [==============================] - 195s 374ms/step - loss: 0.1742 - accuracy: 0.9458 - recall: 0.9491 - precision: 0.9103 - val_loss: 0.1475 - val_accuracy: 0.9550 - val_recall: 0.7231 - val_precision: 0.9257 - lr: 3.1250e-04
# Epoch 22/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1717 - accuracy: 0.9472 - recall: 0.9503 - precision: 0.9127 - val_loss: 0.1520 - val_accuracy: 0.9514 - val_recall: 0.6912 - val_precision: 0.9297 - lr: 3.1250e-04
# Epoch 23/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1696 - accuracy: 0.9476 - recall: 0.9495 - precision: 0.9140 - val_loss: 0.1512 - val_accuracy: 0.9517 - val_recall: 0.6912 - val_precision: 0.9321 - lr: 3.1250e-04
# Epoch 24/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1689 - accuracy: 0.9482 - recall: 0.9503 - precision: 0.9149 - val_loss: 0.1485 - val_accuracy: 0.9533 - val_recall: 0.7067 - val_precision: 0.9288 - lr: 3.1250e-06
# Epoch 25/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1687 - accuracy: 0.9488 - recall: 0.9510 - precision: 0.9157 - val_loss: 0.1478 - val_accuracy: 0.9533 - val_recall: 0.7076 - val_precision: 0.9277 - lr: 3.1250e-06
# Epoch 26/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1682 - accuracy: 0.9489 - recall: 0.9511 - precision: 0.9159 - val_loss: 0.1480 - val_accuracy: 0.9533 - val_recall: 0.7076 - val_precision: 0.9277 - lr: 3.1250e-06
# Epoch 27/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1686 - accuracy: 0.9483 - recall: 0.9507 - precision: 0.9147 - val_loss: 0.1478 - val_accuracy: 0.9533 - val_recall: 0.7076 - val_precision: 0.9277 - lr: 3.1250e-08
# Epoch 28/35
# 519/519 [==============================] - 195s 375ms/step - loss: 0.1683 - accuracy: 0.9487 - recall: 0.9508 - precision: 0.9157 - val_loss: 0.1481 - val_accuracy: 0.9533 - val_recall: 0.7076 - val_precision: 0.9277 - lr: 3.1250e-08

# %%
plot_histories([model_g_history.history ], False )

# %%
test_dataset = create_tf_dataset(test_data).batch(32)

# %%
# latest model
loss, accuracy,precision, recall = model_g_custom.evaluate(test_dataset)

print("Loss: ", loss) 			#
print("Accuracy: ", accuracy) 	#
print("Recall: ", recall) 		#
print('Precision = ', precision)#
# Out:
# 241/241 [==============================] - 4s 13ms/step - loss: 0.1374 - accuracy: 0.9603 - recall: 0.7487 - precision: 0.9226
# Loss:  0.13737256824970245
# Accuracy:  0.9602968096733093
# Recall:  0.9225888252258301
# Precision =  0.7487126588821411

# %%
# best model in terms of loss

from keras.models import load_model

loaded_model = load_model(best_loss)
loss, accuracy, precision, recall = loaded_model.evaluate(test_dataset)

print("Loss: ", loss) 			# 0.2357979118824005
print("Accuracy: ", accuracy) 	# 0.9073157906532288
print("Recall: ", recall) 		# 0.4984551966190338
print("Precision: ", precision) # 0.6826516389846802
# Out:
# 241/241 [==============================] - 4s 12ms/step - loss: 0.1362 - accuracy: 0.9616 - recall: 0.7539 - precision: 0.9289
# Loss:  0.13618159294128418
# Accuracy:  0.9615985155105591
# Recall:  0.9289340376853943
# Precision:  0.7538620233535767
